# %%
# %matplotlib inline

# %% [markdown]
# # Using Statsbomb
# Getting familiar with Statsbomb data

# %%
#importing SBopen class from mplsoccer to open the data
from mplsoccer import Sbopen
# The first thing we have to do is open the data. We use a parser SBopen available in mplsoccer.
parser = Sbopen()

# %% [markdown]
# ## Competition data
# Using method *competition* of the parser we can explore competitions to find the competition we are interested in.
# The most important information for us is in the *competition_id* (id of competition) and *season_id*.
# The first one is the key in Statsbomb database of a competition, the second one of a season
# of this competition (for example WC 2018 would have a different *season_id* than WC 2014, but the same *competition_id*).

# %%
#opening data using competition method
df_competition = parser.competition()
#structure of data
df_competition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67 entries, 0 to 66
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   competition_id             67 non-null     int64
#  1   season_id                  67 non-null     int64
#  2   country_name               67 non-null     object
#  3   competition_name           67 non-null     object
#  4   competition_gender         67 non-null     object
#  5   competition_youth          67 non-null     bool
#  6   competition_international  67 non-null     bool
#  7   season_name                67 non-null     object
#  8   match_updated              67 non-null     object
#  9   match_updated_360          51 non-null     object
#  10  match_available_360        5 non-null      object
#  11  match_available            67 non-null     object
# dtypes: bool(2), int64(2), object(8)
# memory usage: 5.5+ KB

# %% [markdown]
# ## Match data
# Using method *match* of the parser we can explore matches of a competition to find the match we are interested in.
# To open it we need to know the *competition_id* (id of competition) and *season_id*.
# We know that for Women World Cup *competition_id* is 72 and *season_id* is 107.
# From this dataframe for us the most important imformation is provided in *match_id*,
# *home_team_id* and *home_team_name* and adequately *away_team_id* and *away_team_name*.

# %%
#opening data using match method
df_match = parser.match(competition_id=72, season_id=107)
#structure of data
df_match.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 52 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   match_id                         64 non-null     int64
#  1   match_date                       64 non-null     datetime64[ns]
#  2   kick_off                         64 non-null     datetime64[ns]
#  3   home_score                       64 non-null     int64
#  4   away_score                       64 non-null     int64
#  5   match_status                     64 non-null     object
#  6   match_status_360                 64 non-null     object
#  7   last_updated                     64 non-null     datetime64[ns]
#  8   last_updated_360                 64 non-null     datetime64[ns]
#  9   match_week                       64 non-null     int64
#  10  competition_id                   64 non-null     int64
#  11  country_name                     64 non-null     object
#  12  competition_name                 64 non-null     object
#  13  season_id                        64 non-null     int64
#  14  season_name                      64 non-null     object
#  15  home_team_id                     64 non-null     int64
#  16  home_team_name                   64 non-null     object
#  17  home_team_gender                 64 non-null     object
#  18  home_team_group                  0 non-null      object
#  19  home_team_country_id             64 non-null     int64
#  20  home_team_country_name           64 non-null     object
#  21  home_team_managers_id            64 non-null     int64
#  22  home_team_managers_name          64 non-null     object
#  23  home_team_managers_nickname      64 non-null     object
#  24  home_team_managers_dob           62 non-null     datetime64[ns]
#  25  home_team_managers_country_id    64 non-null     int64
#  26  home_team_managers_country_name  64 non-null     object
#  27  away_team_id                     64 non-null     int64
#  28  away_team_name                   64 non-null     object
#  29  away_team_gender                 64 non-null     object
#  30  away_team_group                  0 non-null      object
#  31  away_team_country_id             64 non-null     int64
#  32  away_team_country_name           64 non-null     object
#  33  away_team_managers_id            64 non-null     int64
#  34  away_team_managers_name          64 non-null     object
#  35  away_team_managers_nickname      64 non-null     object
#  36  away_team_managers_dob           61 non-null     datetime64[ns]
#  37  away_team_managers_country_id    64 non-null     int64
#  38  away_team_managers_country_name  64 non-null     object
#  39  metadata_data_version            64 non-null     object
#  40  metadata_shot_fidelity_version   64 non-null     object
#  41  metadata_xy_fidelity_version     64 non-null     object
#  42  competition_stage_id             64 non-null     int64
#  43  competition_stage_name           64 non-null     object
#  44  stadium_id                       64 non-null     int64
#  45  stadium_name                     64 non-null     object
#  46  stadium_country_id               64 non-null     int64
#  47  stadium_country_name             64 non-null     object
#  48  referee_id                       63 non-null     float64
#  49  referee_name                     63 non-null     object
#  50  referee_country_id               63 non-null     float64
#  51  referee_country_name             63 non-null     object
# dtypes: datetime64[ns](6), float64(2), int64(17), object(27)
# memory usage: 26.1+ KB

# %%
df_match.sort_values('match_id')
# Out:
#     match_id match_date            kick_off  home_score  away_score  \
# 38   3893787 2023-07-20 2023-07-20 10:00:00           1           0
# 32   3893788 2023-07-20 2023-07-20 13:00:00           1           0
# 34   3893789 2023-07-21 2023-07-21 08:00:00           0           2
# 9    3893790 2023-07-21 2023-07-21 05:30:00           0           0
# 37   3893791 2023-07-21 2023-07-21 10:30:00           3           0
# ..       ...        ...                 ...         ...         ...
# 11   3902968 2023-08-12 2023-08-12 10:00:00           0           0
# 3    3904628 2023-08-15 2023-08-15 11:00:00           2           1
# 0    3904629 2023-08-16 2023-08-16 13:00:00           1           3
# 2    3906389 2023-08-19 2023-08-19 11:00:00           2           0
# 1    3906390 2023-08-20 2023-08-20 13:00:00           1           0
#
#    match_status match_status_360               last_updated  \
# 38    available        available 2023-08-01 12:35:43.246812
# 32    available        available 2023-08-04 15:33:59.340634
# 34    available        available 2023-08-05 10:25:42.521031
# 9     available        available 2023-08-15 01:27:08.890984
# 37    available        available 2023-08-24 15:30:43.549537
# ..          ...              ...                        ...
# 11    available        available 2023-08-31 14:29:37.548707
# 3     available        available 2023-08-16 03:41:23.763496
# 0     available        available 2023-08-30 11:15:11.306289
# 2     available        available 2023-08-29 21:16:28.091391
# 1     available        available 2023-08-22 19:29:29.948278
#
#              last_updated_360  match_week  ...  competition_stage_id  \
# 38 2023-08-01 12:37:30.380662           1  ...                    10
# 32 2023-08-04 15:35:05.088854           1  ...                    10
# 34 2023-08-05 10:26:26.483897           1  ...                    10
# 9  2023-08-15 01:27:44.637065           1  ...                    10
# 37 2023-08-24 15:33:45.726341           1  ...                    10
# ..                        ...         ...  ...                   ...
# 11 2023-08-31 14:34:02.359150           5  ...                    11
# 3  2023-08-16 11:30:31.556462           6  ...                    15
# 0  2023-08-30 11:17:47.551826           6  ...                    15
# 2  2023-08-29 21:19:57.035390           7  ...                    25
# 1  2023-08-22 19:38:43.965521           7  ...                    26
#
#    competition_stage_name stadium_id                 stadium_name  \
# 38            Group Stage      28892                    Eden Park
# 32            Group Stage     117593                Accor Stadium
# 34            Group Stage    1001341                 Forsyth Barr
# 9             Group Stage      28886                    AAMI Park
# 37            Group Stage      98115  Wellington Regional Stadium
# ..                    ...        ...                          ...
# 11         Quarter-finals      28884             Brisbane Stadium
# 3             Semi-finals      28892                    Eden Park
# 0             Semi-finals     117593                Accor Stadium
# 2         3rd Place Final      28884             Brisbane Stadium
# 1                   Final     117593                Accor Stadium
#
#    stadium_country_id  stadium_country_name referee_id  \
# 38                163           New Zealand     2546.0
# 32                 14             Australia     2426.0
# 34                163           New Zealand  1006259.0
# 9                  14             Australia      965.0
# 37                 14             Australia     2388.0
# ..                ...                   ...        ...
# 11                 14             Australia     2476.0
# 3                 163           New Zealand     2426.0
# 0                  14             Australia     1171.0
# 2                  14             Australia      833.0
# 1                  14             Australia     1171.0
#
#                  referee_name referee_country_id      referee_country_name
# 38          Yoshimi Yamashita              114.0                     Japan
# 32        Edina Alves Batista               31.0                    Brazil
# 34  Vincentia Enyonam Amedome              228.0                      Togo
# 9             Lina Lehtovaara               77.0                   Finland
# 37              Casey Reibelt               14.0                 Australia
# ..                        ...                ...                       ...
# 11  María Belén Carvajal Peña               45.0                     Chile
# 3         Edina Alves Batista               31.0                    Brazil
# 0                  Tori Penso              241.0  United States of America
# 2               Cheryl Foster              249.0                     Wales
# 1                  Tori Penso              241.0  United States of America
#
# [64 rows x 52 columns]

# %% [markdown]
# ## Lineup data
# To check the lineups we use the *lineup* method. We do it for Spain - England WWC 2023 game - *game_id* is 3906390 - you can check that in the df_match. In this dataframe you will find all players who played in this game, their teams
# and jersey numbers.

# %%
# opening data using match method
df_lineup = parser.lineup(3906390)
# structure of data
df_lineup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   player_id        46 non-null     int64
#  1   player_name      46 non-null     object
#  2   player_nickname  46 non-null     object
#  3   jersey_number    46 non-null     int64
#  4   match_id         46 non-null     int64
#  5   team_id          46 non-null     int64
#  6   team_name        46 non-null     object
#  7   country_id       46 non-null     int64
#  8   country_name     46 non-null     object
# dtypes: int64(5), object(4)
# memory usage: 3.4+ KB

# %% [markdown]
# ## Event data
# The Statsbomb data that we will use the most during the course is event data.
# Knowing *game_id* you can open all the events that occured on the pitch
# In the event dataframe you will find events with additional information, we will mostly use this dataframe.
# Tactics dataframe provides information about player position on the pitch. 'Related' dataframe provides information
# on events that were related to each other - for example ball pass and pressure applied. *df_freeze* consists of freezed
# frames with player position in the moment of shots. We will learn more about tracking data later in the course.
# Below, an example of event data is presented.

# %%
#opening data
df_event, df_related, df_freeze, df_tactics = parser.event(3906390)

#structure of data
df_event.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3581 entries, 0 to 3580
# Data columns (total 73 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              3581 non-null   object
#  1   index                           3581 non-null   int64
#  2   period                          3581 non-null   int64
#  3   timestamp                       3581 non-null   object
#  4   minute                          3581 non-null   int64
#  5   second                          3581 non-null   int64
#  6   possession                      3581 non-null   int64
#  7   duration                        2684 non-null   float64
#  8   match_id                        3581 non-null   int64
#  9   type_id                         3581 non-null   int64
#  10  type_name                       3581 non-null   object
#  11  possession_team_id              3581 non-null   int64
#  12  possession_team_name            3581 non-null   object
#  13  play_pattern_id                 3581 non-null   int64
#  14  play_pattern_name               3581 non-null   object
#  15  team_id                         3581 non-null   int64
#  16  team_name                       3581 non-null   object
#  17  tactics_formation               6 non-null      object
#  18  player_id                       3567 non-null   float64
#  19  player_name                     3567 non-null   object
#  20  position_id                     3567 non-null   float64
#  21  position_name                   3567 non-null   object
#  22  pass_recipient_id               897 non-null    float64
#  23  pass_recipient_name             897 non-null    object
#  24  pass_length                     927 non-null    float64
#  25  pass_angle                      927 non-null    float64
#  26  pass_height_id                  927 non-null    float64
#  27  pass_height_name                927 non-null    object
#  28  end_x                           1704 non-null   float64
#  29  end_y                           1704 non-null   float64
#  30  body_part_id                    939 non-null    float64
#  31  body_part_name                  939 non-null    object
#  32  sub_type_id                     335 non-null    float64
#  33  sub_type_name                   335 non-null    object
#  34  x                               3551 non-null   float64
#  35  y                               3551 non-null   float64
#  36  outcome_id                      527 non-null    float64
#  37  outcome_name                    527 non-null    object
#  38  counterpress                    146 non-null    float64
#  39  under_pressure                  957 non-null    float64
#  40  out                             38 non-null     float64
#  41  aerial_won                      40 non-null     object
#  42  foul_committed_advantage        6 non-null      object
#  43  foul_won_advantage              6 non-null      object
#  44  off_camera                      51 non-null     float64
#  45  pass_cross                      28 non-null     object
#  46  ball_recovery_recovery_failure  14 non-null     object
#  47  shot_statsbomb_xg               22 non-null     float64
#  48  end_z                           14 non-null     float64
#  49  technique_id                    42 non-null     float64
#  50  technique_name                  42 non-null     object
#  51  shot_first_time                 11 non-null     object
#  52  goalkeeper_position_id          22 non-null     float64
#  53  goalkeeper_position_name        22 non-null     object
#  54  pass_switch                     25 non-null     object
#  55  dribble_nutmeg                  2 non-null      object
#  56  foul_won_defensive              6 non-null      object
#  57  pass_assisted_shot_id           16 non-null     object
#  58  pass_shot_assist                15 non-null     object
#  59  shot_key_pass_id                16 non-null     object
#  60  pass_cut_back                   2 non-null      object
#  61  pass_goal_assist                1 non-null      object
#  62  dribble_overrun                 4 non-null      object
#  63  ball_recovery_offensive         2 non-null      object
#  64  pass_no_touch                   1 non-null      object
#  65  substitution_replacement_id     6 non-null      float64
#  66  substitution_replacement_name   6 non-null      object
#  67  pass_deflected                  1 non-null      object
#  68  foul_committed_card_id          2 non-null      float64
#  69  foul_committed_card_name        2 non-null      object
#  70  foul_committed_penalty          1 non-null      object
#  71  shot_deflected                  1 non-null      object
#  72  block_deflection                1 non-null      object
# dtypes: float64(24), int64(10), object(39)
# memory usage: 2.0+ MB

# %%
df_related.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7008 entries, 0 to 5503
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   match_id           7008 non-null   int64
#  1   id                 7008 non-null   object
#  2   index              7008 non-null   int64
#  3   type_name          7008 non-null   object
#  4   id_related         7008 non-null   object
#  5   index_related      7008 non-null   int64
#  6   type_name_related  7008 non-null   object
# dtypes: int64(3), object(4)
# memory usage: 438.0+ KB

# %%
df_freeze.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   teammate         255 non-null    bool
#  1   match_id         255 non-null    int64
#  2   id               255 non-null    object
#  3   x                255 non-null    float64
#  4   y                255 non-null    float64
#  5   player_id        255 non-null    int64
#  6   player_name      255 non-null    object
#  7   position_id      255 non-null    int64
#  8   position_name    255 non-null    object
#  9   event_freeze_id  255 non-null    int64
# dtypes: bool(1), float64(2), int64(4), object(3)
# memory usage: 18.3+ KB

# %%
df_tactics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 66 entries, 0 to 65
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   jersey_number     66 non-null     int64
#  1   match_id          66 non-null     int64
#  2   id                66 non-null     object
#  3   player_id         66 non-null     int64
#  4   player_name       66 non-null     object
#  5   position_id       66 non-null     int64
#  6   position_name     66 non-null     object
#  7   event_tactics_id  66 non-null     int64
# dtypes: int64(5), object(3)
# memory usage: 4.2+ KB

# %% [markdown]
# ## 360 data
# Statsbomb offers 360 data which track not only location of an event but also players' location. To open them we need
# an id of game. Later, we will also need id of the event. In the *df_frame* we find information on players' position (but only if teammate, not all information)
# and in *df_visible* it is provided which part of the pitch was tracked during an event.

# %%
df_frame, df_visible = parser.frame(3788741)

# exploring the data
df_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45737 entries, 0 to 45736
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   teammate  45737 non-null  bool
#  1   actor     45737 non-null  bool
#  2   keeper    45737 non-null  bool
#  3   match_id  45737 non-null  int64
#  4   id        45737 non-null  object
#  5   x         45737 non-null  float64
#  6   y         45737 non-null  float64
# dtypes: bool(3), float64(2), int64(1), object(1)
# memory usage: 1.5+ MB

# %%
df_visible.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3370 entries, 0 to 3369
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   match_id      3370 non-null   int64
#  1   id            3370 non-null   object
#  2   visible_area  3370 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 79.1+ KB

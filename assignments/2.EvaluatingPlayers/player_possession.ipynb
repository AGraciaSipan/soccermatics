# %%
# %matplotlib inline

# %% [markdown]
# # Radar plots
#
# In this lesson, we go step-by-step through the process of making player radars
# for a striker. We calculate the following metrics directly from
# a count of actions in the Wyscout event data,
#
# - Non-penalty goals
# - Assists
# - Key passes
# - Smart passes
# - Ariel duels won
# - Ground attacking duels won
#
# We add to these our own calculations of
#
# - non-penalty expected goals
# - passes ending in final third
# - receptions in final third

# %%
import pandas as pd
import numpy as np
import json
# plotting
import matplotlib.pyplot as plt
# statistical fitting of models
import statsmodels.api as sm
import statsmodels.formula.api as smf
#opening data
import os
import pathlib
import warnings 
#used for plots
from scipy import stats
from mplsoccer import PyPizza, FontManager

pd.options.mode.chained_assignment = None
warnings.filterwarnings('ignore')

# %%
PITCH_MAX_X = 105
PITCH_MAX_Y = 68
GOAL_WIDTH = 7.32

WYSCOUT_PITCH_MAX_X = 100
WYSCOUT_PITCH_MAX_Y = 100
WYSCOUT_BOX_X = 84
WYSCOUT_BOX_MIN_Y = 19
WYSCOUT_BOX_MAX_Y = 81

# %%
TRANSFORM_X = PITCH_MAX_X / WYSCOUT_PITCH_MAX_X
TRANSFORM_Y = PITCH_MAX_Y / WYSCOUT_PITCH_MAX_Y

BOX_X = WYSCOUT_BOX_X * TRANSFORM_X
BOX_MIN_Y = WYSCOUT_BOX_MIN_Y * TRANSFORM_Y
BOX_MAX_Y = WYSCOUT_BOX_MAX_Y * TRANSFORM_Y

# %% [markdown]
# ## Opening data
# For this task we will use Wyscout data. We open it, save in the dataframe
# *events_df*. To avoid potential errors, we keep
# only the data for which the beginning and end of an action was registered.

# %%
DATA_PATH = os.path.join(str(pathlib.Path().resolve().parents[1]), 'data', 'Wyscout')

# %%
league = 'England'
events_file_name = f'events_{league}.json'
events_path = os.path.join(DATA_PATH, 'events', events_file_name)

events_df = pd.read_json(events_path, encoding='unicode-escape')

# potential data collection error handling
events_df = events_df.loc[events_df.apply (lambda x: len(x.positions) == 2, axis = 1)]

# %%
def transform_x(row, i):
    return row[i]['x'] * TRANSFORM_X

def transform_y(row, i):
    return (WYSCOUT_PITCH_MAX_Y - row[i]['y']) * TRANSFORM_Y

events_df["x"] = events_df.positions.apply(lambda row: transform_x(row, 0))
events_df["y"] = events_df.positions.apply(lambda row: transform_y(row, 0))
events_df["end_x"] = events_df.positions.apply(lambda row: transform_x(row, 1))
events_df["end_y"] = events_df.positions.apply(lambda row: transform_y(row, 1))
events_df
# Out:
#         eventId           subEventName  \
# 0             8            Simple pass
# 1             8              High pass
# 2             8              Head pass
# 3             8              Head pass
# 4             8            Simple pass
# ...         ...                    ...
# 643145        5  Ball out of the field
# 643146        3                 Corner
# 643147        1               Air duel
# 643148        1               Air duel
# 643149       10                   Shot
#
#                                                      tags  playerId  \
# 0                                          [{'id': 1801}]     25413
# 1                                          [{'id': 1801}]    370224
# 2                                          [{'id': 1801}]      3319
# 3                                          [{'id': 1801}]    120339
# 4                                          [{'id': 1801}]    167145
# ...                                                   ...       ...
# 643145                                                 []         0
# 643146           [{'id': 302}, {'id': 801}, {'id': 1801}]     70965
# 643147                        [{'id': 701}, {'id': 1802}]      7919
# 643148                        [{'id': 703}, {'id': 1801}]      8005
# 643149  [{'id': 403}, {'id': 201}, {'id': 1216}, {'id'...      8005
#
#                                          positions  matchId     eventName  \
# 0         [{'y': 49, 'x': 49}, {'y': 78, 'x': 31}]  2499719          Pass
# 1         [{'y': 78, 'x': 31}, {'y': 75, 'x': 51}]  2499719          Pass
# 2         [{'y': 75, 'x': 51}, {'y': 71, 'x': 35}]  2499719          Pass
# 3         [{'y': 71, 'x': 35}, {'y': 95, 'x': 41}]  2499719          Pass
# 4         [{'y': 95, 'x': 41}, {'y': 88, 'x': 72}]  2499719          Pass
# ...                                            ...      ...           ...
# 643145   [{'y': 32, 'x': 0}, {'y': 100, 'x': 100}]  2500098  Interruption
# 643146  [{'y': 100, 'x': 100}, {'y': 47, 'x': 88}]  2500098     Free Kick
# 643147    [{'y': 53, 'x': 12}, {'y': 50, 'x': 14}]  2500098          Duel
# 643148    [{'y': 47, 'x': 88}, {'y': 50, 'x': 86}]  2500098          Duel
# 643149      [{'y': 50, 'x': 86}, {'y': 0, 'x': 0}]  2500098          Shot
#
#         teamId matchPeriod     eventSec subEventId         id       x      y  \
# 0         1609          1H     2.758649         85  177959171   51.45  34.68
# 1         1609          1H     4.946850         83  177959172   32.55  14.96
# 2         1609          1H     6.542188         82  177959173   53.55  17.00
# 3         1609          1H     8.143395         82  177959174   36.75  19.72
# 4         1609          1H    10.302366         85  177959175   43.05   3.40
# ...        ...         ...          ...        ...        ...     ...    ...
# 643145    1623          2H  2796.732525         50  251596409    0.00  46.24
# 643146    1633          2H  2829.821084         30  251596232  105.00   0.00
# 643147    1623          2H  2831.211419         10  251596410   12.60  31.96
# 643148    1633          2H  2832.434399         10  251596234   92.40  36.04
# 643149    1633          2H  2834.127168        100  251596236   90.30  34.00
#
#          end_x  end_y
# 0        32.55  14.96
# 1        53.55  17.00
# 2        36.75  19.72
# 3        43.05   3.40
# 4        75.60   8.16
# ...        ...    ...
# 643145  105.00   0.00
# 643146   92.40  36.04
# 643147   14.70  34.00
# 643148   90.30  34.00
# 643149    0.00  68.00
#
# [643032 rows x 16 columns]

# %% [markdown]
# ## Minutes played
# All data on our plot will be per 90 minutes played. Therefore, we need an information on the number of minutes played
# throughout the season. To do so, we will use a prepared file that bases on the idea developed by students
# taking part in course in 2021. Files with miutes per game for players in top 5 leagues can be found
# [here](https://github.com/soccermatics/Soccermatics/tree/main/course/lessons/minutes_played). After downloading data and saving
# it in out directory, we open it and store in a dataframe. Then we calculate the sum of miutes played in a season for each player.

# %%
minutes_path = os.path.join(DATA_PATH, 'minutes_played', f'minutes_played_per_game_{league}.json')
minutes_per_game = pd.read_json(minutes_path, encoding='unicode-escape')
minutes_per_game.head()
# Out:
#    playerId        shortName  matchId  teamId    teamName  player_in_min  \
# 0      9206          C. Wood  2500089    1646  Burnley FC              0
# 1      9127         S. Vokes  2500089    1646  Burnley FC             61
# 2        93  J. Guðmunds­son  2500089    1646  Burnley FC              0
# 3      9179         N. Wells  2500089    1646  Burnley FC             80
# 4     10108          K. Long  2500089    1646  Burnley FC              0
#
#    player_out_min  minutesPlayed  red_card
# 0              61             61         0
# 1              95             34         0
# 2              80             80         0
# 3              95             15         0
# 4              95             95         0

# %% [markdown]
# ## Calculating possession
# As the next step we would like to adjust our plot by the player's team ball possession while they
# were on the pitch. To do it, for each row of our dataframe with minutes per player per each game
# we take all the events that were made in this game while the player was on the pitch.
#
# We will also use duels, but
# don't include lost air duels and lost ground defending duels. Why? Possession is calculated as number of touches by team divided
# by the number all touches. If a player lost ground defending duel, that means that he could have been dribbled by, so he did not
# touch the ball. If they lost the air duel, they lost a header. Therefore, we claim that those were mostly events where player may have not
# touched the ball (or if he did the team did not take control over it). We sum
# both team passes and these duels and all passes and these duels in this period. We store these values in a
# dictionary. Then, summing them for each player separately and calculating their ratio, we get
# the possession of the ball by player's team while he was on the pitch. As the last step we merge it with our summary dataframe.

# %%
possession_dict = {}
# for every row in the dataframe
for i, row in minutes_per_game.iterrows():
    # take player id, team id and match id, minute in and minute out
    player_id, team_id, match_id = row["playerId"], row["teamId"], row["matchId"]
    
    # create a key in dictionary if player encounterd first time
    player_key = (player_id, team_id)
    if player_key not in possession_dict:
        possession_dict[player_key] = {'team_passes': 0, 'all_passes' : 0}
    
    # get min in and out of the player
    min_in = row["player_in_min"] * 60
    min_out = row["player_out_min"] * 60
    
    # get the dataframe of events from the game
    match_df = events_df.loc[events_df["matchId"] == match_id].copy()
    
    # add to 2H the highest sec value of 1H
    match_df.loc[match_df["matchPeriod"] == "2H", 'eventSec'] = match_df.loc[match_df["matchPeriod"] == "2H", 'eventSec'] + match_df.loc[match_df["matchPeriod"] == "1H"]["eventSec"].iloc[-1]
    
    # take all events from this game and this period
    player_in_match_df = match_df.loc[match_df["eventSec"] > min_in].loc[match_df["eventSec"] <= min_out]
    
    # take all passes and won duels as described
    all_passes = player_in_match_df.loc[player_in_match_df["eventName"].isin(["Pass", "Duel"])]
    
    # adjusting for no passes in this period (Tuanzebe)
    if len(all_passes) > 0:
        # removing lost air duels
        no_contact = all_passes.loc[all_passes["subEventName"].isin(["Air duel", "Ground defending duel","Ground loose ball duel"])].loc[all_passes.apply(lambda x:{'id':701} in x.tags, axis = 1)]
        all_passes = all_passes.drop(no_contact.index)
    
    # take team passes 
    team_passes = all_passes.loc[all_passes["teamId"] == team_id]
    # append it {(player id, team id): {team passes: sum, all passes : sum}}
    possession_dict[player_key]["team_passes"] += len(team_passes)
    possession_dict[player_key]["all_passes"] += len(all_passes)

possession_dict
# Out:
# {(9206, 1646): {'team_passes': 8653, 'all_passes': 19358},
#  (9127, 1646): {'team_passes': 5097, 'all_passes': 11610},
#  (93, 1646): {'team_passes': 14957, 'all_passes': 34126},
#  (9179, 1646): {'team_passes': 378, 'all_passes': 802},
#  (10108, 1646): {'team_passes': 7420, 'all_passes': 17123},
#  (8433, 1646): {'team_passes': 13085, 'all_passes': 29551},
#  (8125, 1646): {'team_passes': 18037, 'all_passes': 41079},
#  (9433, 1646): {'team_passes': 14990, 'all_passes': 33575},
#  (8980, 1646): {'team_passes': 12531, 'all_passes': 28448},
#  (8643, 1646): {'team_passes': 12072, 'all_passes': 27557},
#  (12242, 1646): {'team_passes': 16477, 'all_passes': 37717},
#  (86325, 1623): {'team_passes': 703, 'all_passes': 1405},
#  (56, 1623): {'team_passes': 1613, 'all_passes': 3075},
#  (32636, 1623): {'team_passes': 5869, 'all_passes': 12544},
#  (7879, 1623): {'team_passes': 6787, 'all_passes': 14587},
#  (353236, 1623): {'team_passes': 10674, 'all_passes': 23675},
#  (9194, 1623): {'team_passes': 4999, 'all_passes': 11118},
#  (8245, 1623): {'team_passes': 11764, 'all_passes': 26321},
#  (8239, 1623): {'team_passes': 11203, 'all_passes': 24021},
#  (145692, 1623): {'team_passes': 6007, 'all_passes': 13226},
#  (10131, 1623): {'team_passes': 19849, 'all_passes': 43438},
#  (25706, 1623): {'team_passes': 16210, 'all_passes': 34891},
#  (8143, 1623): {'team_passes': 12531, 'all_passes': 27570},
#  (7919, 1623): {'team_passes': 14626, 'all_passes': 32198},
#  (8240, 1623): {'team_passes': 6035, 'all_passes': 12903},
#  (26499, 1633): {'team_passes': 10814, 'all_passes': 23934},
#  (265318, 1633): {'team_passes': 4533, 'all_passes': 10389},
#  (41174, 1633): {'team_passes': 11739, 'all_passes': 25651},
#  (20620, 1633): {'team_passes': 8882, 'all_passes': 19758},
#  (8582, 1633): {'team_passes': 17099, 'all_passes': 37669},
#  (8005, 1633): {'team_passes': 5584, 'all_passes': 12117},
#  (14703, 1633): {'team_passes': 13193, 'all_passes': 28687},
#  (21100, 1633): {'team_passes': 15960, 'all_passes': 35944},
#  (379209, 1633): {'team_passes': 7756, 'all_passes': 18064},
#  (70965, 1633): {'team_passes': 5691, 'all_passes': 12552},
#  (37725, 1633): {'team_passes': 15845, 'all_passes': 34236},
#  (3582, 1633): {'team_passes': 9122, 'all_passes': 21524},
#  (8313, 1633): {'team_passes': 18420, 'all_passes': 40647},
#  (8561, 1633): {'team_passes': 13165, 'all_passes': 30185},
#  (7970, 1633): {'team_passes': 4473, 'all_passes': 8931},
#  (7934, 1611): {'team_passes': 13432, 'all_passes': 24323},
#  (7910, 1611): {'team_passes': 24601, 'all_passes': 44995},
#  (7918, 1611): {'team_passes': 14518, 'all_passes': 26568},
#  (71703, 1611): {'team_passes': 9748, 'all_passes': 17450},
#  (7922, 1611): {'team_passes': 18656, 'all_passes': 34683},
#  (7938, 1611): {'team_passes': 20062, 'all_passes': 37244},
#  (4255, 1651): {'team_passes': 1489, 'all_passes': 3428},
#  (91381, 1651): {'team_passes': 10851, 'all_passes': 24945},
#  (3278, 1651): {'team_passes': 11893, 'all_passes': 26085},
#  (241564, 1625): {'team_passes': 5441, 'all_passes': 7602},
#  (26136, 1625): {'team_passes': 3113, 'all_passes': 4624},
#  (8324, 1625): {'team_passes': 2635, 'all_passes': 3593},
#  (353241, 1625): {'team_passes': 223, 'all_passes': 272},
#  (8307, 1625): {'team_passes': 13268, 'all_passes': 18984},
#  (254898, 1613): {'team_passes': 6167, 'all_passes': 13669},
#  (8945, 1624): {'team_passes': 14566, 'all_passes': 24983},
#  (48, 1624): {'team_passes': 25044, 'all_passes': 41929},
#  (136441, 1624): {'team_passes': 18335, 'all_passes': 30737},
#  (8677, 1633): {'team_passes': 7383, 'all_passes': 16201},
#  (280157, 1633): {'team_passes': 139, 'all_passes': 356},
#  (215983, 1619): {'team_passes': 8337, 'all_passes': 15597},
#  (86239, 1619): {'team_passes': 3161, 'all_passes': 5540},
#  (8566, 1651): {'team_passes': 204, 'all_passes': 332},
#  (16122, 1673): {'team_passes': 7979, 'all_passes': 16988},
#  (8959, 1659): {'team_passes': 7907, 'all_passes': 16713},
#  (8944, 1646): {'team_passes': 13664, 'all_passes': 31460},
#  (397168, 1628): {'team_passes': 8719, 'all_passes': 19686},
#  (14870, 1612): {'team_passes': 15961, 'all_passes': 27489},
#  (21160, 1644): {'team_passes': 5255, 'all_passes': 10323},
#  (18550, 1612): {'team_passes': 16348, 'all_passes': 28628},
#  (8460, 1659): {'team_passes': 12454, 'all_passes': 26867},
#  (434159, 1627): {'team_passes': 2673, 'all_passes': 6645},
#  (355937, 1623): {'team_passes': 6880, 'all_passes': 15266},
#  (15198, 1639): {'team_passes': 11696, 'all_passes': 27181},
#  (7961, 1639): {'team_passes': 2329, 'all_passes': 4837},
#  (92947, 1639): {'team_passes': 1480, 'all_passes': 4062},
#  (3326, 1639): {'team_passes': 3024, 'all_passes': 7448},
#  (55224, 1628): {'team_passes': 1707, 'all_passes': 4576},
#  (77558, 1623): {'team_passes': 12984, 'all_passes': 28512},
#  (64966, 1651): {'team_passes': 6761, 'all_passes': 14866},
#  (15823, 1673): {'team_passes': 6035, 'all_passes': 14623},
#  (8495, 1610): {'team_passes': 4037, 'all_passes': 8003},
#  (217078, 1631): {'team_passes': 3009, 'all_passes': 6280},
#  (192748, 1631): {'team_passes': 5802, 'all_passes': 12535},
#  (8553, 1633): {'team_passes': 8611, 'all_passes': 18301},
#  (224206, 1633): {'team_passes': 1309, 'all_passes': 2881},
#  (340, 1623): {'team_passes': 10863, 'all_passes': 23429},
#  (77546, 1623): {'team_passes': 10786, 'all_passes': 23374},
#  (8583, 1628): {'team_passes': 546, 'all_passes': 1289},
#  (286825, 1623): {'team_passes': 8851, 'all_passes': 20405},
#  (8314, 1627): {'team_passes': 10169, 'all_passes': 24051},
#  (70085, 1623): {'team_passes': 805, 'all_passes': 1655},
#  (11294, 1646): {'team_passes': 6667, 'all_passes': 16005},
#  (9164, 1646): {'team_passes': 4891, 'all_passes': 11427},
#  (189821, 1644): {'team_passes': 6254, 'all_passes': 12853},
#  (291528, 1644): {'team_passes': 112, 'all_passes': 146},
#  (7892, 1610): {'team_passes': 5921, 'all_passes': 11016},
#  (8826, 1613): {'team_passes': 4951, 'all_passes': 11575},
#  (8004, 1613): {'team_passes': 9020, 'all_passes': 21610},
#  (262, 10531): {'team_passes': 7965, 'all_passes': 18123},
#  (471, 10531): {'team_passes': 4247, 'all_passes': 9198},
#  (15474, 1673): {'team_passes': 160, 'all_passes': 498},
#  (8362, 1627): {'team_passes': 2233, 'all_passes': 6162},
#  (8516, 1646): {'team_passes': 5965, 'all_passes': 13522},
#  (7929, 1644): {'team_passes': 11822, 'all_passes': 23698},
#  (26010, 1609): {'team_passes': 3457, 'all_passes': 5445},
#  (340476, 1633): {'team_passes': 21, 'all_passes': 48},
#  (25865, 1628): {'team_passes': 2739, 'all_passes': 6231},
#  (447538, 1619): {'team_passes': 61, 'all_passes': 153},
#  (77536, 1624): {'team_passes': 614, 'all_passes': 1063},
#  (70092, 1646): {'team_passes': 10497, 'all_passes': 23929},
#  (8624, 1623): {'team_passes': 1343, 'all_passes': 2737},
#  (25885, 1644): {'team_passes': 2566, 'all_passes': 5744},
#  (8627, 1644): {'team_passes': 2690, 'all_passes': 5892},
#  (442211, 1673): {'team_passes': 1473, 'all_passes': 2566},
#  (3657, 1651): {'team_passes': 4750, 'all_passes': 10711},
#  (212651, 1610): {'team_passes': 297, 'all_passes': 512},
#  (38093, 1610): {'team_passes': 2741, 'all_passes': 4870},
#  (415748, 1639): {'team_passes': 958, 'all_passes': 2229},
#  (65254, 1639): {'team_passes': 6964, 'all_passes': 16250},
#  (7879, 1609): {'team_passes': 661, 'all_passes': 994},
#  (134351, 1659): {'team_passes': 3313, 'all_passes': 6772},
#  (8284, 1623): {'team_passes': 4425, 'all_passes': 10381},
#  (25572, 1633): {'team_passes': 5251, 'all_passes': 10840},
#  (274488, 1673): {'team_passes': 1489, 'all_passes': 2800},
#  (288865, 10531): {'team_passes': 1911, 'all_passes': 3640},
#  (3361, 1609): {'team_passes': 12579, 'all_passes': 20782},
#  (258162, 10531): {'team_passes': 4530, 'all_passes': 9380},
#  (25415, 1619): {'team_passes': 1338, 'all_passes': 2395},
#  (397163, 1611): {'team_passes': 0, 'all_passes': 0},
#  (8514, 1612): {'team_passes': 13517, 'all_passes': 23166},
#  (119630, 1631): {'team_passes': 1621, 'all_passes': 3502},
#  (447812, 1639): {'team_passes': 2626, 'all_passes': 6252},
#  (255935, 1651): {'team_passes': 1771, 'all_passes': 4353},
#  (9283, 1659): {'team_passes': 5926, 'all_passes': 12110},
#  (8186, 1628): {'team_passes': 8210, 'all_passes': 17847},
#  (8142, 1628): {'team_passes': 3344, 'all_passes': 7109},
#  (70085, 1625): {'team_passes': 4328, 'all_passes': 6458},
#  (105338, 1611): {'team_passes': 6707, 'all_passes': 12184},
#  (3343, 1639): {'team_passes': 813, 'all_passes': 2356},
#  (448038, 1639): {'team_passes': 113, 'all_passes': 247},
#  (3802, 1612): {'team_passes': 8958, 'all_passes': 15229},
#  (4365, 10531): {'team_passes': 4630, 'all_passes': 10080},
#  (7864, 1609): {'team_passes': 1266, 'all_passes': 2437},
#  (8391, 1628): {'team_passes': 5721, 'all_passes': 12319},
#  (337225, 1613): {'team_passes': 707, 'all_passes': 1959},
#  (37726, 1613): {'team_passes': 3360, 'all_passes': 8500},
#  (7974, 1613): {'team_passes': 7467, 'all_passes': 18016},
#  (8752, 1646): {'team_passes': 188, 'all_passes': 449},
#  (20420, 1611): {'team_passes': 830, 'all_passes': 1420},
#  (8498, 1631): {'team_passes': 2911, 'all_passes': 6531},
#  (4255, 1631): {'team_passes': 206, 'all_passes': 376},
#  (240070, 1624): {'team_passes': 6003, 'all_passes': 10422},
#  (281135, 1619): {'team_passes': 892, 'all_passes': 1876},
#  (61941, 1619): {'team_passes': 12198, 'all_passes': 23280},
#  (415747, 1659): {'team_passes': 231, 'all_passes': 981},
#  (62344, 10531): {'team_passes': 99, 'all_passes': 248},
#  (25604, 1613): {'team_passes': 328, 'all_passes': 823},
#  (5911, 1623): {'team_passes': 1736, 'all_passes': 3480},
#  (406682, 1623): {'team_passes': 801, 'all_passes': 1991},
#  (26610, 1633): {'team_passes': 1783, 'all_passes': 4110},
#  (370, 1619): {'team_passes': 6819, 'all_passes': 13208},
#  (423162, 1610): {'team_passes': 129, 'all_passes': 186},
#  (128214, 1613): {'team_passes': 580, 'all_passes': 1237},
#  (237268, 1612): {'team_passes': 140, 'all_passes': 281},
#  (279709, 1673): {'team_passes': 908, 'all_passes': 2017},
#  (9623, 1646): {'team_passes': 6473, 'all_passes': 15479},
#  (8935, 1639): {'team_passes': 1571, 'all_passes': 3438},
#  (8761, 1673): {'team_passes': 1026, 'all_passes': 2506},
#  (92922, 1623): {'team_passes': 754, 'all_passes': 1789},
#  (7907, 1612): {'team_passes': 3683, 'all_passes': 5819},
#  (8992, 1624): {'team_passes': 737, 'all_passes': 1150},
#  (8126, 1633): {'team_passes': 3810, 'all_passes': 7984},
#  (8096, 1627): {'team_passes': 456, 'all_passes': 1070},
#  (15301, 1651): {'team_passes': 104, 'all_passes': 199},
#  (270828, 1624): {'team_passes': 16, 'all_passes': 25},
#  (13745, 1628): {'team_passes': 111, 'all_passes': 216},
#  (8374, 1627): {'team_passes': 1052, 'all_passes': 2436},
#  (62091, 1651): {'team_passes': 868, 'all_passes': 2122},
#  (3557, 1613): {'team_passes': 548, 'all_passes': 1223},
#  (9622, 1651): {'team_passes': 870, 'all_passes': 2080},
#  (531655, 1628): {'team_passes': 177, 'all_passes': 281},
#  (77502, 1646): {'team_passes': 1560, 'all_passes': 3362},
#  (8272, 1644): {'team_passes': 923, 'all_passes': 1885},
#  (7868, 1609): {'team_passes': 2037, 'all_passes': 3136},
#  (14886, 1623): {'team_passes': 213, 'all_passes': 600},
#  (32968, 1644): {'team_passes': 1147, 'all_passes': 2379},
#  (269676, 1624): {'team_passes': 24, 'all_passes': 33},
#  (297258, 1628): {'team_passes': 67, 'all_passes': 219},
#  (227756, 1610): {'team_passes': 144, 'all_passes': 206},
#  (20450, 1639): {'team_passes': 329, 'all_passes': 864},
#  (447254, 1627): {'team_passes': 98, 'all_passes': 269},
#  (134708, 1612): {'team_passes': 69, 'all_passes': 177}}

# %%
# Create a list of dictionaries to store the data
data_list = []

# Calculate the possession percentage and store it in a list of dictionaries
for key, value in possession_dict.items():
    player_id, team_id = key
    team_passes = value["team_passes"]
    all_passes = value["all_passes"]
    
    possession_percentage = team_passes / all_passes if all_passes > 0 else 0
    
    data_list.append({"playerId": player_id, "teamId": team_id, "possession": possession_percentage})

# Create a DataFrame from the list of dictionaries
percentage_df = pd.DataFrame(data_list)
percentage_df.to_json(os.path.join(DATA_PATH, 'player_possession', f'player_possession_{league}.json'))
percentage_df.head()
# Out:
#    playerId  teamId  possession
# 0      9206    1646    0.446999
# 1      9127    1646    0.439018
# 2        93    1646    0.438288
# 3      9179    1646    0.471322
# 4     10108    1646    0.433335

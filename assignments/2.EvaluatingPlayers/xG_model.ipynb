# %%
import os
import pandas as pd
import pathlib
import numpy as np

from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
import statsmodels.formula.api as smf

import joblib

# %%
DATA_PATH = os.path.join(str(pathlib.Path().resolve().parents[1]), 'data', 'Wyscout')

# %%
PITCH_MAX_X = 105
PITCH_MAX_Y = 68
GOAL_WIDTH = 7.32

WYSCOUT_PITCH_MAX_X = 100
WYSCOUT_PITCH_MAX_Y = 100
WYSCOUT_BOX_X = 84
WYSCOUT_BOX_MIN_Y = 19
WYSCOUT_BOX_MAX_Y = 81

# %%
TRANSFORM_X = PITCH_MAX_X / WYSCOUT_PITCH_MAX_X
TRANSFORM_Y = PITCH_MAX_Y / WYSCOUT_PITCH_MAX_Y

BOX_X = WYSCOUT_BOX_X * TRANSFORM_X
BOX_MIN_Y = WYSCOUT_BOX_MIN_Y * TRANSFORM_Y
BOX_MAX_Y = WYSCOUT_BOX_MAX_Y * TRANSFORM_Y

# %%
leagues = ['England', 'France', 'Germany', 'Italy', 'Spain']
all_events_df = pd.DataFrame() 

for league in leagues:
    events_file_name = f'events_{league}.json'
    events_path = os.path.join(DATA_PATH, 'events', events_file_name)

    events_df = pd.read_json(events_path, encoding='unicode-escape')
    events_df = events_df.loc[events_df.apply (lambda x: len(x.positions) == 2, axis = 1)]
    
    all_events_df = pd.concat([all_events_df, events_df], ignore_index=True)
    
# chains_df[["subEventName", "playerId", "matchId", "possession_chain", ]]
all_events_df
# Out:
#          eventId  subEventName                          tags  playerId  \
# 0              8   Simple pass                [{'id': 1801}]     25413
# 1              8     High pass                [{'id': 1801}]    370224
# 2              8     Head pass                [{'id': 1801}]      3319
# 3              8     Head pass                [{'id': 1801}]    120339
# 4              8   Simple pass                [{'id': 1801}]    167145
# ...          ...           ...                           ...       ...
# 3070681        8   Simple pass                [{'id': 1801}]     20623
# 3070682        7  Acceleration                [{'id': 1801}]    122832
# 3070683        8         Cross   [{'id': 401}, {'id': 1802}]    122832
# 3070684        8   Simple pass                [{'id': 1801}]     40756
# 3070685        7     Clearance  [{'id': 1401}, {'id': 1802}]      3306
#
#                                          positions  matchId  \
# 0         [{'y': 49, 'x': 49}, {'y': 78, 'x': 31}]  2499719
# 1         [{'y': 78, 'x': 31}, {'y': 75, 'x': 51}]  2499719
# 2         [{'y': 75, 'x': 51}, {'y': 71, 'x': 35}]  2499719
# 3         [{'y': 71, 'x': 35}, {'y': 95, 'x': 41}]  2499719
# 4         [{'y': 95, 'x': 41}, {'y': 88, 'x': 72}]  2499719
# ...                                            ...      ...
# 3070681    [{'y': 25, 'x': 66}, {'y': 2, 'x': 88}]  2565927
# 3070682    [{'y': 2, 'x': 88}, {'y': 21, 'x': 97}]  2565927
# 3070683   [{'y': 21, 'x': 97}, {'y': 26, 'x': 92}]  2565927
# 3070684     [{'y': 74, 'x': 8}, {'y': 56, 'x': 9}]  2565927
# 3070685  [{'y': 56, 'x': 9}, {'y': 100, 'x': 100}]  2565927
#
#                   eventName  teamId matchPeriod     eventSec subEventId  \
# 0                      Pass    1609          1H     2.758649         85
# 1                      Pass    1609          1H     4.946850         83
# 2                      Pass    1609          1H     6.542188         82
# 3                      Pass    1609          1H     8.143395         82
# 4                      Pass    1609          1H    10.302366         85
# ...                     ...     ...         ...          ...        ...
# 3070681                Pass     682          2H  2939.077491         85
# 3070682  Others on the ball     682          2H  2940.515560         70
# 3070683                Pass     682          2H  2942.098761         80
# 3070684                Pass     675          2H  2943.089232         85
# 3070685  Others on the ball     675          2H  2943.668846         71
#
#                 id
# 0        177959171
# 1        177959172
# 2        177959173
# 3        177959174
# 4        177959175
# ...            ...
# 3070681  253302671
# 3070682  253302673
# 3070683  253302674
# 3070684  253302698
# 3070685  253302695
#
# [3070686 rows x 12 columns]

# %%
def transform_x(row, i):
    return row[i]['x'] * TRANSFORM_X

def transform_y(row, i):
    return (WYSCOUT_PITCH_MAX_Y - row[i]['y']) * TRANSFORM_Y

all_events_df["x"] = all_events_df.positions.apply(lambda row: transform_x(row, 0))
all_events_df["y"] = all_events_df.positions.apply(lambda row: transform_y(row, 0))
all_events_df["end_x"] = all_events_df.positions.apply(lambda row: transform_x(row, 1))
all_events_df["end_y"] = all_events_df.positions.apply(lambda row: transform_y(row, 1))
all_events_df
# Out:
#          eventId  subEventName                          tags  playerId  \
# 0              8   Simple pass                [{'id': 1801}]     25413
# 1              8     High pass                [{'id': 1801}]    370224
# 2              8     Head pass                [{'id': 1801}]      3319
# 3              8     Head pass                [{'id': 1801}]    120339
# 4              8   Simple pass                [{'id': 1801}]    167145
# ...          ...           ...                           ...       ...
# 3070681        8   Simple pass                [{'id': 1801}]     20623
# 3070682        7  Acceleration                [{'id': 1801}]    122832
# 3070683        8         Cross   [{'id': 401}, {'id': 1802}]    122832
# 3070684        8   Simple pass                [{'id': 1801}]     40756
# 3070685        7     Clearance  [{'id': 1401}, {'id': 1802}]      3306
#
#                                          positions  matchId  \
# 0         [{'y': 49, 'x': 49}, {'y': 78, 'x': 31}]  2499719
# 1         [{'y': 78, 'x': 31}, {'y': 75, 'x': 51}]  2499719
# 2         [{'y': 75, 'x': 51}, {'y': 71, 'x': 35}]  2499719
# 3         [{'y': 71, 'x': 35}, {'y': 95, 'x': 41}]  2499719
# 4         [{'y': 95, 'x': 41}, {'y': 88, 'x': 72}]  2499719
# ...                                            ...      ...
# 3070681    [{'y': 25, 'x': 66}, {'y': 2, 'x': 88}]  2565927
# 3070682    [{'y': 2, 'x': 88}, {'y': 21, 'x': 97}]  2565927
# 3070683   [{'y': 21, 'x': 97}, {'y': 26, 'x': 92}]  2565927
# 3070684     [{'y': 74, 'x': 8}, {'y': 56, 'x': 9}]  2565927
# 3070685  [{'y': 56, 'x': 9}, {'y': 100, 'x': 100}]  2565927
#
#                   eventName  teamId matchPeriod     eventSec subEventId  \
# 0                      Pass    1609          1H     2.758649         85
# 1                      Pass    1609          1H     4.946850         83
# 2                      Pass    1609          1H     6.542188         82
# 3                      Pass    1609          1H     8.143395         82
# 4                      Pass    1609          1H    10.302366         85
# ...                     ...     ...         ...          ...        ...
# 3070681                Pass     682          2H  2939.077491         85
# 3070682  Others on the ball     682          2H  2940.515560         70
# 3070683                Pass     682          2H  2942.098761         80
# 3070684                Pass     675          2H  2943.089232         85
# 3070685  Others on the ball     675          2H  2943.668846         71
#
#                 id       x      y   end_x  end_y
# 0        177959171   51.45  34.68   32.55  14.96
# 1        177959172   32.55  14.96   53.55  17.00
# 2        177959173   53.55  17.00   36.75  19.72
# 3        177959174   36.75  19.72   43.05   3.40
# 4        177959175   43.05   3.40   75.60   8.16
# ...            ...     ...    ...     ...    ...
# 3070681  253302671   69.30  51.00   92.40  66.64
# 3070682  253302673   92.40  66.64  101.85  53.72
# 3070683  253302674  101.85  53.72   96.60  50.32
# 3070684  253302698    8.40  17.68    9.45  29.92
# 3070685  253302695    9.45  29.92  105.00   0.00
#
# [3070686 rows x 16 columns]

# %%
shots = all_events_df[all_events_df["eventName"] == "Shot"].copy()
shots
# Out:
#          eventId subEventName  \
# 46            10         Shot
# 62            10         Shot
# 91            10         Shot
# 128           10         Shot
# 249           10         Shot
# ...          ...          ...
# 3070350       10         Shot
# 3070401       10         Shot
# 3070567       10         Shot
# 3070623       10         Shot
# 3070664       10         Shot
#
#                                                       tags  playerId  \
# 46       [{'id': 101}, {'id': 402}, {'id': 201}, {'id':...     25413
# 62       [{'id': 401}, {'id': 201}, {'id': 1211}, {'id'...     26150
# 91       [{'id': 101}, {'id': 403}, {'id': 201}, {'id':...     14763
# 128      [{'id': 401}, {'id': 201}, {'id': 1215}, {'id'...      7868
# 249      [{'id': 402}, {'id': 201}, {'id': 1205}, {'id'...      7868
# ...                                                    ...       ...
# 3070350  [{'id': 1901}, {'id': 402}, {'id': 2101}, {'id...    267134
# 3070401          [{'id': 402}, {'id': 2101}, {'id': 1802}]    267134
# 3070567  [{'id': 101}, {'id': 401}, {'id': 201}, {'id':...    134174
# 3070623  [{'id': 402}, {'id': 201}, {'id': 1206}, {'id'...      3321
# 3070664  [{'id': 401}, {'id': 201}, {'id': 1212}, {'id'...      4498
#
#                                           positions  matchId eventName  \
# 46           [{'y': 41, 'x': 88}, {'y': 0, 'x': 0}]  2499719      Shot
# 62       [{'y': 52, 'x': 85}, {'y': 100, 'x': 100}]  2499719      Shot
# 91       [{'y': 52, 'x': 96}, {'y': 100, 'x': 100}]  2499719      Shot
# 128          [{'y': 33, 'x': 81}, {'y': 0, 'x': 0}]  2499719      Shot
# 249          [{'y': 30, 'x': 75}, {'y': 0, 'x': 0}]  2499719      Shot
# ...                                             ...      ...       ...
# 3070350      [{'y': 66, 'x': 93}, {'y': 0, 'x': 0}]  2565927      Shot
# 3070401      [{'y': 32, 'x': 90}, {'y': 0, 'x': 0}]  2565927      Shot
# 3070567      [{'y': 25, 'x': 92}, {'y': 0, 'x': 0}]  2565927      Shot
# 3070623  [{'y': 30, 'x': 82}, {'y': 100, 'x': 100}]  2565927      Shot
# 3070664  [{'y': 43, 'x': 88}, {'y': 100, 'x': 100}]  2565927      Shot
#
#          teamId matchPeriod     eventSec subEventId         id       x      y  \
# 46         1609          1H    94.595788        100  177959212   92.40  40.12
# 62         1631          1H   179.854785        100  177959247   89.25  32.64
# 91         1631          1H   254.745027        100  177959280  100.80  32.64
# 128        1609          1H   425.824035        100  177959289   85.05  45.56
# 249        1609          1H   815.462015        100  177959429   78.75  47.60
# ...         ...         ...          ...        ...        ...     ...    ...
# 3070350     682          2H  1776.027412        100  253302272   97.65  23.12
# 3070401     682          2H  1944.188119        100  253302329   94.50  46.24
# 3070567     682          2H  2385.837008        100  253302547   96.60  51.00
# 3070623     675          2H  2722.835144        100  253302642   86.10  47.60
# 3070664     675          2H  2857.346465        100  253302686   92.40  38.76
#
#          end_x  end_y
# 46         0.0   68.0
# 62       105.0    0.0
# 91       105.0    0.0
# 128        0.0   68.0
# 249        0.0   68.0
# ...        ...    ...
# 3070350    0.0   68.0
# 3070401    0.0   68.0
# 3070567    0.0   68.0
# 3070623  105.0    0.0
# 3070664  105.0    0.0
#
# [40461 rows x 16 columns]

# %%
def calculate_distance_and_angle(x, y):
    c = abs(y - PITCH_MAX_Y / 2)
    d = PITCH_MAX_X - x
    distance = np.sqrt(d ** 2 + c ** 2)
    angle = np.arctan((GOAL_WIDTH * d) / (d ** 2 + c ** 2 - (GOAL_WIDTH / 2) ** 2))
    angle = angle + np.pi * (angle <= 0)
    
    return distance, angle

shots["distance"], shots["angle"] = zip(*shots.apply(lambda row: calculate_distance_and_angle(row["x"], row["y"]), axis=1))

scaler = StandardScaler()
# shots["distance"] = scaler.fit_transform(shots["distance"].values.reshape(-1, 1))
# shots["angle"] = scaler.fit_transform(shots["angle"].values.reshape(-1, 1))

# find goals
shots["isGoal"] = shots.tags.apply(lambda x: 1 if {'id': 101} in x else 0).astype(object)


# headers have id = 403
headers = shots.loc[shots.apply (lambda x: {'id': 403} in x.tags, axis = 1)]
non_headers = shots.drop(headers.index)

# %%
def build_xG_model(formula, data):
    return smf.glm(formula=formula, data=data, family=sm.families.Binomial()).fit()

formula = "isGoal ~ distance + angle"
headers_model = build_xG_model(formula=formula, data=headers)
non_headers_model = build_xG_model(formula=formula, data=non_headers)

# %%
def predict_xG(model, df):
    params = model.params
    return 1 / (1 + np.exp(params[0] + params[1] * df['distance'] + params[2] * df['angle']))

headers_xG = predict_xG(headers_model, headers)
non_headers_xG = predict_xG(non_headers_model, non_headers)

# %%
headers = headers.assign(xG = headers_xG)
non_headers = non_headers.assign(xG = non_headers_xG)

all_shots_xg = pd.concat([non_headers, headers])
all_shots_xg
# Out:
#          eventId subEventName  \
# 46            10         Shot
# 62            10         Shot
# 128           10         Shot
# 249           10         Shot
# 394           10         Shot
# ...          ...          ...
# 3068556       10         Shot
# 3068790       10         Shot
# 3069492       10         Shot
# 3070177       10         Shot
# 3070272       10         Shot
#
#                                                       tags  playerId  \
# 46       [{'id': 101}, {'id': 402}, {'id': 201}, {'id':...     25413
# 62       [{'id': 401}, {'id': 201}, {'id': 1211}, {'id'...     26150
# 128      [{'id': 401}, {'id': 201}, {'id': 1215}, {'id'...      7868
# 249      [{'id': 402}, {'id': 201}, {'id': 1205}, {'id'...      7868
# 394              [{'id': 401}, {'id': 2101}, {'id': 1802}]      7945
# ...                                                    ...       ...
# 3068556  [{'id': 101}, {'id': 403}, {'id': 201}, {'id':...    225946
# 3068790  [{'id': 403}, {'id': 201}, {'id': 1202}, {'id'...      3335
# 3069492  [{'id': 101}, {'id': 403}, {'id': 201}, {'id':...      3322
# 3070177  [{'id': 403}, {'id': 201}, {'id': 1203}, {'id'...    274435
# 3070272  [{'id': 101}, {'id': 403}, {'id': 201}, {'id':...    267134
#
#                                           positions  matchId eventName  \
# 46           [{'y': 41, 'x': 88}, {'y': 0, 'x': 0}]  2499719      Shot
# 62       [{'y': 52, 'x': 85}, {'y': 100, 'x': 100}]  2499719      Shot
# 128          [{'y': 33, 'x': 81}, {'y': 0, 'x': 0}]  2499719      Shot
# 249          [{'y': 30, 'x': 75}, {'y': 0, 'x': 0}]  2499719      Shot
# 394          [{'y': 39, 'x': 90}, {'y': 0, 'x': 0}]  2499719      Shot
# ...                                             ...      ...       ...
# 3068556  [{'y': 60, 'x': 91}, {'y': 100, 'x': 100}]  2565926      Shot
# 3068790  [{'y': 54, 'x': 91}, {'y': 100, 'x': 100}]  2565926      Shot
# 3069492  [{'y': 48, 'x': 93}, {'y': 100, 'x': 100}]  2565927      Shot
# 3070177      [{'y': 40, 'x': 91}, {'y': 0, 'x': 0}]  2565927      Shot
# 3070272      [{'y': 29, 'x': 88}, {'y': 0, 'x': 0}]  2565927      Shot
#
#          teamId matchPeriod     eventSec subEventId         id      x      y  \
# 46         1609          1H    94.595788        100  177959212  92.40  40.12
# 62         1631          1H   179.854785        100  177959247  89.25  32.64
# 128        1609          1H   425.824035        100  177959289  85.05  45.56
# 249        1609          1H   815.462015        100  177959429  78.75  47.60
# 394        1609          1H  1286.061650        100  177959606  94.50  41.48
# ...         ...         ...          ...        ...        ...    ...    ...
# 3068556     684          2H  1832.038735        100  253222172  95.55  27.20
# 3068790     684          2H  2828.726041        100  253222439  95.55  31.28
# 3069492     675          1H  1893.736105        100  253301228  97.65  35.36
# 3070177     682          2H  1263.415273        100  253302113  95.55  40.80
# 3070272     682          2H  1501.813224        100  253302208  92.40  48.28
#
#          end_x  end_y   distance     angle isGoal        xG
# 46         0.0   68.0  14.007655  0.467241      1  0.138584
# 62       105.0    0.0  15.808608  0.453557      0  0.114647
# 128        0.0   68.0  23.057235  0.274666      0  0.042662
# 249        0.0   68.0  29.563872  0.219665      0  0.019770
# 394        0.0   68.0  12.891873  0.466040      0  0.153457
# ...        ...    ...        ...       ...    ...       ...
# 3068556  105.0    0.0  11.642272  0.515285      1  0.076085
# 3068790  105.0    0.0   9.833662  0.692985      0  0.117039
# 3069492  105.0    0.0   7.474764  0.902493      1  0.193131
# 3070177    0.0   68.0  11.642272  0.515285      0  0.076085
# 3070272    0.0   68.0  19.044117  0.258168      1  0.021572
#
# [40461 rows x 20 columns]

# %%
headers_model.params
# Out:
# Intercept    1.657052
# distance     0.131463
# angle       -1.340644
# dtype: float64

# %%
non_headers_model.params
# Out:
# Intercept    1.034281
# distance     0.108651
# angle       -1.560485
# dtype: float64

# %%
model_filename = 'headers_xG_model.sav'
path_model = os.path.join(str(pathlib.Path().resolve().parents[1]), 'models', model_filename)
joblib.dump(headers_model, path_model)
# Out:
# ['C:\\Users\\Alvaro\\repos\\soccermatics\\models\\headers_xG_model.sav']

# %%
model_filename = 'non_headers_xG_model.sav'
path_model = os.path.join(str(pathlib.Path().resolve().parents[1]), 'models', model_filename)
joblib.dump(non_headers_model, path_model)
# Out:
# ['C:\\Users\\Alvaro\\repos\\soccermatics\\models\\non_headers_xG_model.sav']
